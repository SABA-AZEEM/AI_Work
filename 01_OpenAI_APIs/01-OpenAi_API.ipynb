# %%
# !pip install openai
import openai
openai.api_key='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'
def Sentiment_Analysis(text):
  messages=[
      {"role"   :"system",
       "content":f"""You are trained to analyze and detect the sentiment of
                  given text.If you're unsure about text,say i'm not sure
                  about it."""
      },
      {
        "role":'user',
        "content":f"""Analyze the following text, and return the answer in a
                  single word,as it's positive or negative.And the text is:
                  {text}"""
      }
  ]

  response=openai.ChatCompletion.create(
      model='gpt-3.5-turbo',
      messages=messages,
      max_tokens=1,
      n=1,
      stop=None,
      temperature=0
  )
  return response.choices[0].message.content;

#calling the function
text="I love to read books."
response=Sentiment_Analysis(text);
print(f"""Sentiment of {text} is: {response}""");
# Out:
# ...
# Sentiment of I love to read books. is: Positive
