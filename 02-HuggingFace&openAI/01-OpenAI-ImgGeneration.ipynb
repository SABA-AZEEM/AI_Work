# %%
# !pip install openai
import openai
openai.api_key="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"

#function
def generate_image(text):
  #Generate the image using open-ai DALL-E model
  response=openai.Image.create(
      prompt=text,
      n=1,
      size='256x256'
  )
  img_url=response.data[0]['url']
  print(img_url);
#call function
generate_image("A white cat");
# Out:
# ...
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-Akkwmi7N7K9wVSvIboLP24Z5/user-ti16PxwL07T8OxtjOcyFtXvM/img-vV9CQdxCYMmWbbvtixHaXFQe.png?st=2023-09-08T07%3A46%3A35Z&se=2023-09-08T09%3A46%3A35Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-09-07T18%3A22%3A39Z&ske=2023-09-08T18%3A22%3A39Z&sks=b&skv=2021-08-06&sig=4VPxuwaUQcxyHBaNXC8dSm1JCgO/d6tvkdJKuRBrE/I%3D
